# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/ML_Preprocessing/Feature Engineering/Outliers/placement.csv", usecols=[0, 1])

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks
# 0  7.19                  26.0
# 1  7.46                  38.0
# 2  7.54                  40.0
# 3  6.42                   8.0
# 4  7.23                  17.0

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,1])
plt.xlabel('CGPA')
plt.ylabel("Package (in lpa)")
plt.show()
