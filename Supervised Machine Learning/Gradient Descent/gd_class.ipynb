# %%
import matplotlib.pyplot as plt
import numpy as np
from rich import color
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=200, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([69.95492877])

# %%
reg.intercept_
# Out:
# np.float64(1.261134946734599)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color='red')

# %% [markdown]
# ## When your `m` is constant

# %%
class GDregressor:
    def __init__(self, learning_rate, epochs):
        self.m = 69.95
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self, X, y):
        #calculate the b using GD
        for i in range(self.epochs):
            loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope)
            print(f'slope:{self.m} and b:{self.b}')

# %%
gd = GDregressor(0.001,100)

# %%
gd.fit(X,y)
# Out:
# slope:21.37 and b:-71.73497024599737
# slope:21.37 and b:-42.77595239359581
# slope:21.37 and b:-25.40054168215487
# slope:21.37 and b:-14.975295255290305
# slope:21.37 and b:-8.72014739917157
# slope:21.37 and b:-4.967058685500327
# slope:21.37 and b:-2.715205457297581
# slope:21.37 and b:-1.3640935203759337
# slope:21.37 and b:-0.5534263582229457
# slope:21.37 and b:-0.06702606093115193
# slope:21.37 and b:0.22481411744392404
# slope:21.37 and b:0.3999182244689689
# slope:21.37 and b:0.5049806886839965
# slope:21.37 and b:0.5680181672130131
# slope:21.37 and b:0.6058406543304231
# slope:21.37 and b:0.6285341466008691
# slope:21.37 and b:0.642150241963136
# slope:21.37 and b:0.6503198991804965
# slope:21.37 and b:0.6552216935109126
# slope:21.37 and b:0.6581627701091634
# slope:21.37 and b:0.6599274160681131
# slope:21.37 and b:0.6609862036434826
# slope:21.37 and b:0.6616214761887037
# slope:21.37 and b:0.6620026397158375
# slope:21.37 and b:0.6622313378321174
# ...

# %% [markdown]
# ## When your `m` is not constant

# %%
class GDregressor:

    def __init__(self, learning_rate, epochs):
        self.m = 100
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self, X, y):

        X = X.ravel()

        for i in range(self.epochs):

            y_pred = self.m * X + self.b

            # correct gradients
            loss_slope_b = -2 * np.sum(y - y_pred)
            loss_slope_m = -2 * np.sum((y - y_pred) * X)

            # update
            self.b = self.b - self.lr * loss_slope_b
            self.m = self.m - self.lr * loss_slope_m

            print(f'slope:{self.m} and b:{self.b}')

    def predict(self, X):
        return self.m * X + self.b

# %%
gd = GDregressor(0.001,100)

# %%
gd.fit(X,y)
# Out:
# slope:86.8024547425865 and b:-71.34748533522341
# slope:79.37931017255207 and b:-42.22101341345913
# slope:75.21273734047558 and b:-24.78171116478035
# slope:72.8794366905811 and b:-14.33866248887933
# slope:71.57611321116367 and b:-8.084331678278726
# slope:70.85018444359889 and b:-4.338155908211531
# slope:70.4471487863957 and b:-2.0940277887087717
# slope:70.2241928091252 and b:-0.7495370576108311
# slope:70.10136327820018 and b:0.05605866456619435
# slope:70.03401460137883 and b:0.5388107997695107
# slope:69.99728886187246 and b:0.8281301898063063
# slope:69.97739051694177 and b:1.001540841125907
# slope:69.96669148357567 and b:1.1054891738175778
# slope:69.96099154724504 and b:1.1678054491035808
# slope:69.957989080046 and b:1.2051671252592788
# slope:69.95642987154724 and b:1.2275693349367407
# slope:69.95563494402587 and b:1.2410029770376851
# slope:69.95523958493857 and b:1.2490592449331284
# slope:69.95504972816373 and b:1.2538910573595632
# ...
