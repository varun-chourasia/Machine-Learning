# %%
import numpy as np
from sklearn import linear_model

n_samples, n_features  = 1, 100

y = np.random.randn(n_samples)
X = np.random.randn(n_samples, n_features)

clf = linear_model.SGDRegressor()

import time

start_time = time.time()

clf.partial_fit(X, y)

elapsed_time = time.time() - start_time

print(elapsed_time)
# Out:
# 0.006892681121826172

# %%
X = np.random.randn(n_samples, n_features)

# %%
clf.partial_fit(X,y)
# Out:
# SGDRegressor()

# %% [markdown]
# ### River
#
# River is a Python library dedicated to online machine learning, where data is treated as a continuous stream of instances. It is the result of a merger between two earlier libraries, creme and scikit-multiflow. River's goal is to be the go-to library for machine learning on streaming data
#
# #### key characteristics:
#
# <ol>
# <li>Incremental Learning: Models learn one data point at a time, which is ideal for applications with continuously generated data like IoT, spam filtering, and recommender systems.
# <li>Memory Efficient: By processing data instance by instance, River avoids the need to store large datasets in memory.
# <li>Scikit-learn Like API: It offers a familiar API with methods like learn_one for training and predict_one for inference, making it easy for those with scikit-learn experience to adapt.
# <li>Stateful Operations: River's models and transformers are stateful, meaning they maintain and update their internal state with each new piece of data.
# <li>Pipelines: It allows for the creation of pipelines that chain preprocessing steps with a model, simplifying the workflow.
# <li>Concept Drift Detection: The library includes tools to detect when the statistical properties of the data stream change over time.
# <ol>

# %%
from river import compose, linear_model, metrics, preprocessing, stream

# Example dataset of phishing websites
dataset = stream.iter_csv(
    'phishing.csv',
    target='is_phishing'
)

# Create a pipeline of a scaler and a logistic regression model
model = compose.Pipeline(
    preprocessing.StandardScaler(),
    linear_model.LogisticRegression()
)

# Initialize a metric to track accuracy
metric = metrics.Accuracy()

# Process the data stream
for x, y in dataset:
    # Make a prediction for the current sample
    y_pred = model.predict_one(x)

    # Update the accuracy metric
    metric.update(y, y_pred)

    # Update the model with the new sample
    model.learn_one(x, y)

print(f"Final accuracy: {metric.get():.2%}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3409412165.py in <cell line: 0>()
# ----> 1 from river import compose, linear_model, metrics, preprocessing, stream
#       2
#       3 # Example dataset of phishing websites
#       4 dataset = stream.iter_csv(
#       5     'phishing.csv',
#
# ModuleNotFoundError: No module named 'river'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
